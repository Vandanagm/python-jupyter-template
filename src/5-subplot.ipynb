# %% [markdown]
# ### Exercise 5: Subplot Layout

# %%
# TASK: Create a 2x2 subplot layout.
# Plot a line chart in the first subplot, a bar chart in the second, a scatter plot in the third, and a pie chart in the fourth.

import matplotlib.pyplot as plt
import numpy as np
try:
    fig, axs = plt.subplots(2, 2, figsize=(10, 8))

    # Line plot
    x = np.linspace(0, 10, 100)
    y = x**2
    axs[0, 0].plot(x, y, color='b', label='y = x^2')
    axs[0, 0].set_title('Line Chart')
    axs[0, 0].set_xlabel('X Values')
    axs[0, 0].set_ylabel('Y Values')
    axs[0, 0].legend()
    axs[0, 0].grid(True)

    # Bar chart
    categories = ['A', 'B', 'C', 'D']
    values = [5, 7, 3, 9]
    colors = ['red', 'blue', 'green', 'purple']
    axs[0, 1].bar(categories, values, color=colors)
    axs[0, 1].set_title('Bar Chart')
    axs[0, 1].set_xlabel('Categories')
    axs[0, 1].set_ylabel('Values')
    axs[0, 1].grid(axis='y', linestyle='--', alpha=0.6)

    # Scatter plot
    x_scatter = [1, 2, 3, 4, 5]
    y_scatter = [2, 4, 6, 8, 10]
    axs[1, 0].scatter(x_scatter, y_scatter, color='magenta', marker='o')
    axs[1, 0].set_title('Scatter Plot')
    axs[1, 0].set_xlabel('X Values')
    axs[1, 0].set_ylabel('Y Values')
    axs[1, 0].grid(True, linestyle='--', alpha=0.6)

    # Pie chart
    labels = ['Python', 'Java', 'C++', 'JavaScript']
    sizes = [40, 25, 20, 15]
    axs[1, 1].pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors, startangle=140, wedgeprops={'edgecolor': 'black'})
    axs[1, 1].set_title('Pie Chart')

    plt.tight_layout()
    plt.show()
except Exception as e:
    print(f"Error generating subplot layout: {e}")
